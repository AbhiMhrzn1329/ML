# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiMhrzn1329/ML/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd
data = {
    "cars": ["bmw", "honda", "suzuki", "byd"],
    "models": ["2007", "2008", "2015", "2024"],
    "passen": ["4", "6", "6", "5"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'byd'],
#  'models': ['2007', '2008', '2015', '2024'],
#  'passen': ['4', '6', '6', '5']}

# %%
# convert the data dictionary to dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2015      6
# 3     byd   2024      5

# %%
df.to_csv("//content/drive/MyDrive/Colab Notebooks/pandas.ipynbcar_data.csv")

# %%
df = pd.read_csv("//content/drive/MyDrive/Colab Notebooks/pandas.ipynbcar_data.csv")
df
# Out:
#    Unnamed: 0    cars  models  passen
# 0           0     bmw    2007       4
# 1           1   honda    2008       6
# 2           2  suzuki    2015       6
# 3           3     byd    2024       5

# %%
#create a dataframe with two features calories and duration.
import pandas as pd
data = {
    "calories": ["420", "500", "390"],
    "duration": ["50", "60", "45"],
}
data
df = pd.DataFrame(data)
